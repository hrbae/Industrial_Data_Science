# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbae/Industrial_Data_Science/blob/main/Code/4_%EC%8B%9C%EA%B0%81%ED%99%94_Part2_%26_%EA%B8%B0%EC%B4%88_%ED%86%B5%EA%B3%84_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = "/content/drive/My Drive/Colab Notebooks/Data" 
data_name = os.listdir(data_path)
iris = pd.read_csv(data_path + '/' + data_name[0])
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Box Plot

# %%
plt.boxplot(iris['SepalLengthCm'])
plt.show()

# %%
plt.boxplot(iris['SepalWidthCm'])
plt.show()

# %% [markdown]
# > Box Plot 한번에 여러개 그리기

# %%
# boxplot 함수 안에 그리고자하는 여러 변수를 입력

plt.boxplot([iris['SepalWidthCm'],iris['SepalLengthCm'],iris['PetalWidthCm'], iris['PetalLengthCm']])
plt.show()

# %%
# list를 이용해서 쉽게 그리기

data = []
data.append(iris['SepalWidthCm'])
data.append(iris['SepalLengthCm'])
data.append(iris['PetalWidthCm'])
data.append(iris['PetalLengthCm'])

plt.boxplot(data)
plt.show()

# %%
# loop를 이용해서 보다 쉽게 list 처리하기
col = list(iris.columns)
print(col)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
# del 함수를 이용해서 list안에 element 제거 (인덱스 기준 삭제)
# id와 species 변수 삭제하기

col = list(iris.columns)
print(col)
del col[0]
print(col)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
del col[4]
print(col)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
# remove 함수를 이용해서 list안에 element 제거 (값 기준 삭제)
# id와 species 변수 삭제하기

col = list(iris.columns)
col.remove('Id')
print(col)
col.remove('Species')
print(col)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
# 동시에 지우기
col = list(iris.columns)
col.remove('ID','Species')
print(col)

# 각 함수들은 하나에 하나씩만 동작하므로 loop와 조건문을 이용해서 처리
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-a5bd3a6d44ce> in <module>()
#       1 # 동시에 지우기
#       2 col = list(iris.columns)
# ----> 3 col.remove('ID','Species')
#       4 print(col)
#
# TypeError: remove() takes exactly one argument (2 given)

# %%
col = list(iris.columns)
del_col = ['Id','Species']

for value in col:
  for del_value in del_col:
    if(value==del_value):
      col.remove(value)
    
print(col)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
col = list(iris.columns)
del_col = ['Id','Species']

for value in col:
  print("현재 확인중인 columns 값은 {} 입니다".format(value))
  for del_value in del_col:
    print("대조중인 column 값은 {}입니다".format(del_value))
    if(value==del_value):
      col.remove(value)
      print("{}가 성공적으로 삭제되었습니다".format(value))
print(col)
# Out:
# 현재 확인중인 columns 값은 Id 입니다
# 대조중인 column 값은 Id입니다
# Id가 성공적으로 삭제되었습니다
# 대조중인 column 값은 Species입니다
# 현재 확인중인 columns 값은 SepalWidthCm 입니다
# 대조중인 column 값은 Id입니다
# 대조중인 column 값은 Species입니다
# 현재 확인중인 columns 값은 PetalLengthCm 입니다
# 대조중인 column 값은 Id입니다
# 대조중인 column 값은 Species입니다
# 현재 확인중인 columns 값은 PetalWidthCm 입니다
# 대조중인 column 값은 Id입니다
# 대조중인 column 값은 Species입니다
# 현재 확인중인 columns 값은 Species 입니다
# 대조중인 column 값은 Id입니다
# 대조중인 column 값은 Species입니다
# Species가 성공적으로 삭제되었습니다
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
data = []
for value in col:
  for col_value in iris.columns:
    if(value == col_value):
      data.append(iris[value])
    
print(data)
# Out:
# [0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64, 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64, 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64, 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64]

# %%
plt.boxplot(data)
plt.show()

# %% [markdown]
# > Figure size 조절하기

# %%
fig = plt.figure(figsize =(10, 7)) 

plt.boxplot([iris['SepalWidthCm'],iris['PetalWidthCm'],iris['SepalLengthCm']])
plt.show()

# %% [markdown]
# > Box plot 더 잘 그려보기

# %%
fig = plt.figure(figsize =(10, 7)) 
ax = fig.add_subplot(111) 
  
# Creating axes instance 
bp = ax.boxplot(data, patch_artist = True, vert = 0)

# %%
fig = plt.figure(figsize =(10, 7)) 
ax = fig.add_subplot(111) 
  
# Creating axes instance 
bp = ax.boxplot(data, patch_artist = False, vert = 0)

# %%
fig = plt.figure(figsize =(10, 7)) 
ax = fig.add_subplot(111) 
  
# Creating axes instance 
bp = ax.boxplot(data, patch_artist = True, 
                notch ='True', vert = 0)

# %%
fig = plt.figure(figsize =(10, 7)) 
ax = fig.add_subplot(111) 
  
# Creating axes instance 
bp = ax.boxplot(data, patch_artist = True, 
                notch ='True', vert = 0) 
  
colors = ['#0000FF', '#00FF00',  
          '#FFFF00', '#FF00FF'] 
  

for patch, color in zip(bp['boxes'], colors): 
    patch.set_facecolor(color) 
  
# changing color and linewidth of 
# whiskers 
for whisker in bp['whiskers']: 
    whisker.set(color ='#8B008B', 
                linewidth = 1.5, 
                linestyle =":") 
  
# changing color and linewidth of 
# caps 
for cap in bp['caps']: 
    cap.set(color ='#8B008B', 
            linewidth = 2) 
  
# changing color and linewidth of 
# medians 
for median in bp['medians']: 
    median.set(color ='red', 
               linewidth = 3) 
  
# changing style of fliers 
for flier in bp['fliers']: 
    flier.set(marker ='D', 
              color ='#e7298a', 
              alpha = 0.5) 
      
# x-axis labels 
ax.set_yticklabels(['data_1', 'data_2',  
                    'data_3', 'data_4']) 
  
# Adding title  
plt.title("Customized box plot") 
  
# Removing top axes and right axes 
# ticks 
ax.get_xaxis().tick_bottom() 
ax.get_yaxis().tick_left() 
      
# show plot 
plt.show(bp)

# %% [markdown]
# > 종 별로 분리해서 box plot 그리기

# %%
species = list(iris['Species'].value_counts().index)

# 종별 PetalLengthCm 차이 비교

data = []
for species_value in species:
  data.append(iris.loc[iris['Species']==species_value,'PetalLengthCm'])

print(data)
# Out:
# [0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# 11    1.6
# 12    1.4
# 13    1.1
# 14    1.2
# 15    1.5
# 16    1.3
# 17    1.4
# 18    1.7
# 19    1.5
# 20    1.7
# 21    1.5
# 22    1.0
# 23    1.7
# 24    1.9
# 25    1.6
# 26    1.6
# 27    1.5
# 28    1.4
# 29    1.6
# 30    1.6
# 31    1.5
# 32    1.5
# 33    1.4
# 34    1.5
# 35    1.2
# 36    1.3
# 37    1.5
# 38    1.3
# 39    1.5
# 40    1.3
# 41    1.3
# 42    1.3
# 43    1.6
# 44    1.9
# 45    1.4
# 46    1.6
# 47    1.4
# 48    1.5
# 49    1.4
# Name: PetalLengthCm, dtype: float64, 100    6.0
# 101    5.1
# 102    5.9
# 103    5.6
# 104    5.8
# 105    6.6
# 106    4.5
# 107    6.3
# 108    5.8
# 109    6.1
# 110    5.1
# 111    5.3
# 112    5.5
# 113    5.0
# 114    5.1
# 115    5.3
# 116    5.5
# 117    6.7
# 118    6.9
# 119    5.0
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# ...

# %%
fig = plt.figure(figsize =(20, 10)) 
ax = fig.add_subplot(111) 
  
# Creating axes instance 
bp = ax.boxplot(data, patch_artist = True, 
                notch ='True', vert = 1) 
  
colors = ['#0000FF', '#00FF00',  
          '#FFFF00', '#FF00FF'] 
  

for patch, color in zip(bp['boxes'], colors): 
    patch.set_facecolor(color) 
  
# changing color and linewidth of 
# whiskers 
for whisker in bp['whiskers']: 
    whisker.set(color ='#8B008B', 
                linewidth = 1.5, 
                linestyle =":") 
  
# changing color and linewidth of 
# caps 
for cap in bp['caps']: 
    cap.set(color ='#8B008B', 
            linewidth = 2) 
  
# changing color and linewidth of 
# medians 
for median in bp['medians']: 
    median.set(color ='red', 
               linewidth = 3) 
  
# changing style of fliers 
for flier in bp['fliers']: 
    flier.set(marker ='D', 
              color ='#e7298a', 
              alpha = 0.5) 
      
# x-axis labels 
ax.set_xticklabels([species[0], species[1],species[2]])

# Adding title  

plt.title("Petal length difference for each species")
#plt.title("Petal length difference for each species", fontsize=30)

  
# Removing top axes and right axes 
# ticks 
ax.get_xaxis().tick_bottom() 
ax.get_yaxis().tick_left() 

'''      
from matplotlib import rcParams
labelsize = 15
rcParams['xtick.labelsize'] = labelsize
rcParams['ytick.labelsize'] = labelsize 
'''  
# show plot 
plt.show(bp)

# %% [markdown]
# # Scatter Plot 그리기 (산점도)

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.scatter(iris['PetalLengthCm'], iris['PetalWidthCm'], c ="pink",  
            linewidths = 2,  
            marker =">",  
            edgecolor ="green",  
            s = 50) 
  
plt.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'], c ="yellow", 
            linewidths = 2, 
            marker ="<",  
            edgecolor ="red",  
            s = 50) 
  
plt.xlabel("X-axis") 
plt.ylabel("Y-axis") 
plt.show()

# %% [markdown]
# > marker 옵션![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# [marker 옵션](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)

# %%
species = list(iris['Species'].value_counts().index)

# 종별 PetalLengthCm과 PetalWidthCm 산점도 차이 비교

data = []
labels = []
for species_value in species:
  data.append(iris.loc[iris['Species']==species_value,['PetalLengthCm','PetalWidthCm']])
  labels.append(species_value)


fig = plt.figure(figsize =(10, 7)) 
plt.scatter(data[0]['PetalLengthCm'], data[0]['PetalWidthCm'], c ="pink",  
            linewidths = 2,  
            marker =">",  
            edgecolor ="green",  
            s = 50) 
  
plt.scatter(data[1]['PetalLengthCm'], data[1]['PetalWidthCm'], c ="yellow", 
            linewidths = 2, 
            marker ="<",  
            edgecolor ="red",  
            s = 50) 

plt.scatter(data[2]['PetalLengthCm'], data[2]['PetalWidthCm'], c ="skyblue", 
            linewidths = 2, 
            marker ="s",  
            edgecolor ="blue",  
            s = 50) 

plt.xlabel("X-axis") 
plt.ylabel("Y-axis") 
plt.legend(labels)
plt.show()

# %%
# 산점도 행렬
import seaborn as sns
sns.pairplot(iris, hue="Species")

# %%
# Pandas 를 이용한 산점도 행렬
from pandas.plotting import scatter_matrix
scatter_matrix(iris, alpha = 0.2, figsize = (6, 6), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbcb8692828>,
# ...
#       dtype=object)

# %% [markdown]
# # 기초 통계분석

# %% [markdown]
# * 통계분석 종류
#
# ![캡처.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   통계 분석 방법론 선택 기준
#
# ![그림1.png](data:image/png;base64,...)

# %% [markdown]
# * t-test: 두 집단간 평균 차이가 유의미한지 검증하는 방법
#
# > t-test 수행을 위한 전제 조건
#
# >> 1. 표본이 독립적인가?
#
# >> 2. 수집된 데이터가 정규분포를 따르는가?
#
# >> 3. 비교 집단이 2개인가?
#
# ![그림1.png](data:image/png;base64,...)

# %% [markdown]
# > [분석예제1] t-test를 이용하여 iris 데이터 속에 존재하는 종 간의 꽃받침과 꽃잎의 길이 및 넓이 차이 분석

# %%
print('Step1: 종별 데이터 분리')
species = iris['Species'].value_counts().index
print(species)
vir = iris.loc[iris['Species']==species[0],:]
ver = iris.loc[iris['Species']==species[1],:]
seto = iris.loc[iris['Species']==species[2],:]
# Out:
# Step1: 종별 데이터 분리
# Index(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], dtype='object')

# %%
diff = vir['PetalLengthCm'].mean() - seto['PetalLengthCm'].mean()
print('통계량: {}'.format(statistic))
print('통계량: {}'.format(statistic))
print('Step2-1: 꽃받침 길이의 평균 차이 검증')
statistic, p_value = scipy.stats.ttest_ind(vir['PetalLengthCm'],ver['PetalLengthCm'])
# Out:
# Step2-1: 꽃받침 길이의 평균 차이 검증
# 통계량: 12.603779441384985
# P value: 3.1788195478061495e-22
# 해석: virginica의 꽃받침 길이와 versicolor의 꽃받침 길이의 평균 차이는 통계적으로 유의하며 virginica의 꽃받침 길이의 평균이 1.292000 만큼 크다.

# %%
tatistic, p_value = scipy.stats.ttest_ind(ver['PetalLengthCm'],seto['PetalLengthCm'])
diff = ver['PetalLengthCm'].mean() - seto['PetalLengthCm'].mean()
print('통계량: {}'.format(statistic))
print('P value: {}'.format(p_value))
print('해석: virginica의 꽃받침 길이와 seto의 꽃받침 길이의 평균 차이는 통계적으로 유의하며 virginica의 꽃받침 길이의 평균이 {:2f} 만큼 크다.'.format(diff))
# Out:
# 통계량: 49.965703359355636
# P value: 5.717463758170621e-62
# 해석: virginica의 꽃받침 길이와 seto의 꽃받침 길이의 평균 차이는 통계적으로 유의하며 virginica의 꽃받침 길이의 평균이 2.796000 만큼 크다.

# %% [markdown]
# #과제
#
# > [과제1] SepalLengthCm에 대한 종간 Box plot을 그리고 t-test를 통해 분석을 수행하시오
#
# >> t-test 수행 결과 및 전체 box plot 그림 함꼐 제출
#
# > [과제2] 각 종에 SepalLengthCm과 SepalWidthCm 각 종별로 구분하고 산점도를 그리시오
#
# >> matplotlib를 이용하여 산점도를 그리시오
